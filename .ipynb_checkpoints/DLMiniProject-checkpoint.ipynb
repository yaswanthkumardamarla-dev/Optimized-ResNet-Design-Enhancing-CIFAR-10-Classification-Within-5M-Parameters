# %%
import numpy as np
import pandas as pd
import os
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split, TensorDataset
from torch.optim.lr_scheduler import StepLR, MultiStepLR
from PIL import Image
import torch.optim.lr_scheduler as lr_scheduler
import matplotlib.pyplot as plt

# auto. choose CPU or GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Function to load CIFAR-10 dataset
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Specify the directory containing CIFAR-10 batches
cifar10_dir = './data'

# Load metadata (labels)
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = [label.decode('utf-8') for label in meta_data_dict[b'label_names']]

# Load training data
train_data = []
train_labels = []
for i in range(1, 6):
    batch = load_cifar_batch(os.path.join(cifar10_dir, f'data_batch_{i}'))
    train_data.append(batch[b'data'])
    train_labels += batch[b'labels']

train_data = np.vstack(train_data).reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1) # Convert to HWC format
train_labels = np.array(train_labels)

# Data augmentation and normalization
transform = transforms.Compose([
    transforms.ToPILImage(),
    #transforms.RandomRotation(10),
    #transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
    transforms.RandomHorizontalFlip(p=0.5),
    #transforms.RandomAdjustSharpness(sharpness_factor=2, p=0.2),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261)),
    #transforms.RandomErasing(p=0.05, scale=(0.02, 0.1), value=1.0, inplace=False)
])

# Convert to TensorDataset and apply transformations
class CustomCIFAR10Dataset(torch.utils.data.Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx]
        label = self.labels[idx]

        if self.transform:
            img = self.transform(img)

        return img, label

train_dataset = CustomCIFAR10Dataset(train_data, train_labels, transform=transform)

test_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
])

batch_test_dict = load_cifar_batch(os.path.join(cifar10_dir, 'test_batch'))
val_images = batch_test_dict[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
val_labels = np.array(batch_test_dict[b'labels'])

val_dataset = CustomCIFAR10Dataset(val_images, val_labels, transform=test_transform)

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=8)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=8)

# Load test dataset
cifar_test_path = 'cifar_test_nolabel.pkl'
test_batch = load_cifar_batch(cifar_test_path)
test_images = test_batch[b'data'].astype(np.float32) / 255.0

test_dataset = [(test_transform(img),) for img in test_images]
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False, num_workers=8)

# Train function
def train_model(model, train_loader, val_loader, epochs=50):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.09, momentum=0.9, weight_decay=3e-4)
    scheduler = MultiStepLR(optimizer, milestones=[80, 120, 150, 180], gamma=0.1)

    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct_train, total_train = 0, 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_losses.append(running_loss / len(train_loader))
        train_accuracies.append(100 * correct_train / total_train)

        model.eval()
        correct_val, total_val = 0, 0
        val_loss = 0.0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(100 * correct_val / total_val)

        scheduler.step()
        print(f'Epoch {epoch+1}/{epochs} - '
              f'Train Loss: {train_losses[-1]:.4f}, Train Acc: {train_accuracies[-1]:.2f}% | '
              f'Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accuracies[-1]:.2f}%')

    # Plot training and validation accuracy/loss
    plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies)

def plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, len(train_losses) + 1)
    
    plt.figure(figsize=(12, 5))
    
    # Loss Plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label="Training Loss", marker='o')
    plt.plot(epochs, val_losses, label="Validation Loss", marker='o')
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training & Validation Loss")
    plt.legend()
    
    # Accuracy Plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label="Training Accuracy", marker='o')
    plt.plot(epochs, val_accuracies, label="Validation Accuracy", marker='o')
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy (%)")
    plt.title("Training & Validation Accuracy")
    plt.legend()
    
    plt.show()


# Define a custom ResNet model from scratch
class BasicBlock(nn.Module):
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1, dropout_prob = 0.17):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.skip = nn.Sequential()
        self.dropout = nn.Dropout(p=dropout_prob)
        if stride != 1 or in_channels != self.expansion * out_channels:
            self.skip = nn.Sequential(
                nn.Conv2d(in_channels, self.expansion * out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * out_channels)
            )

    def forward(self, x):
        identity = x
        if self.skip:
            identity = self.skip(x)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out = self.dropout(out)
        out += identity
        out = self.relu(out)
        return out

class ModifiedResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ModifiedResNet, self).__init__()
        self.in_planes = 32  # Match ModifiedResNet

        self.init_conv = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1, bias=False)
        self.init_bn = nn.BatchNorm2d(32)
        self.relu = nn.ReLU(inplace=True)

        self.layer1 = self._make_layer(block, 32, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 64, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
        #self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=4)

        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Linear(128 * block.expansion, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        layers = []
        strides = [stride] + [1] * (num_blocks - 1)
        for stride in strides:
            layers.append(block(self.in_planes, out_channels, stride))
            self.in_planes = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.init_conv(x)
        out = self.init_bn(out)
        out = self.relu(out)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        #out = self.layer4(out)
        out = self.avg_pool(out)
        out = torch.flatten(out, 1)
        out = self.fc(out)
        return out

# Put model to device
model = ModifiedResNet(BasicBlock, [4, 4, 3, 3]).to(device)

from torchsummary import summary
summary(model, (3, 32, 32))
# Out:
# Using device: cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#             Conv2d-4           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-5           [-1, 32, 32, 32]              64
#               ReLU-6           [-1, 32, 32, 32]               0
#            Dropout-7           [-1, 32, 32, 32]               0
#             Conv2d-8           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-9           [-1, 32, 32, 32]              64
#           Dropout-10           [-1, 32, 32, 32]               0
#              ReLU-11           [-1, 32, 32, 32]               0
#        BasicBlock-12           [-1, 32, 32, 32]               0
#            Conv2d-13           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-14           [-1, 32, 32, 32]              64
#              ReLU-15           [-1, 32, 32, 32]               0
#           Dropout-16           [-1, 32, 32, 32]               0
#            Conv2d-17           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-18           [-1, 32, 32, 32]              64
#           Dropout-19           [-1, 32, 32, 32]               0
#              ReLU-20           [-1, 32, 32, 32]               0
#        BasicBlock-21           [-1, 32, 32, 32]               0
#            Conv2d-22           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-23           [-1, 32, 32, 32]              64
#              ReLU-24           [-1, 32, 32, 32]               0
#           Dropout-25           [-1, 32, 32, 32]               0
#            Conv2d-26           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-27           [-1, 32, 32, 32]              64
#           Dropout-28           [-1, 32, 32, 32]               0
#              ReLU-29           [-1, 32, 32, 32]               0
#        BasicBlock-30           [-1, 32, 32, 32]               0
#            Conv2d-31           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-32           [-1, 32, 32, 32]              64
#              ReLU-33           [-1, 32, 32, 32]               0
#           Dropout-34           [-1, 32, 32, 32]               0
#            Conv2d-35           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-36           [-1, 32, 32, 32]              64
#           Dropout-37           [-1, 32, 32, 32]               0
#              ReLU-38           [-1, 32, 32, 32]               0
#        BasicBlock-39           [-1, 32, 32, 32]               0
#            Conv2d-40           [-1, 64, 16, 16]           2,048
#       BatchNorm2d-41           [-1, 64, 16, 16]             128
#            Conv2d-42           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-43           [-1, 64, 16, 16]             128
#              ReLU-44           [-1, 64, 16, 16]               0
#           Dropout-45           [-1, 64, 16, 16]               0
#            Conv2d-46           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-47           [-1, 64, 16, 16]             128
#           Dropout-48           [-1, 64, 16, 16]               0
#              ReLU-49           [-1, 64, 16, 16]               0
#        BasicBlock-50           [-1, 64, 16, 16]               0
#            Conv2d-51           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-52           [-1, 64, 16, 16]             128
#              ReLU-53           [-1, 64, 16, 16]               0
#           Dropout-54           [-1, 64, 16, 16]               0
#            Conv2d-55           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-56           [-1, 64, 16, 16]             128
#           Dropout-57           [-1, 64, 16, 16]               0
#              ReLU-58           [-1, 64, 16, 16]               0
#        BasicBlock-59           [-1, 64, 16, 16]               0
#            Conv2d-60           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-61           [-1, 64, 16, 16]             128
#              ReLU-62           [-1, 64, 16, 16]               0
#           Dropout-63           [-1, 64, 16, 16]               0
#            Conv2d-64           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-65           [-1, 64, 16, 16]             128
#           Dropout-66           [-1, 64, 16, 16]               0
#              ReLU-67           [-1, 64, 16, 16]               0
#        BasicBlock-68           [-1, 64, 16, 16]               0
#            Conv2d-69           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-70           [-1, 64, 16, 16]             128
#              ReLU-71           [-1, 64, 16, 16]               0
#           Dropout-72           [-1, 64, 16, 16]               0
#            Conv2d-73           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-74           [-1, 64, 16, 16]             128
#           Dropout-75           [-1, 64, 16, 16]               0
#              ReLU-76           [-1, 64, 16, 16]               0
#        BasicBlock-77           [-1, 64, 16, 16]               0
#            Conv2d-78            [-1, 128, 8, 8]           8,192
#       BatchNorm2d-79            [-1, 128, 8, 8]             256
#            Conv2d-80            [-1, 128, 8, 8]          73,728
#       BatchNorm2d-81            [-1, 128, 8, 8]             256
#              ReLU-82            [-1, 128, 8, 8]               0
#           Dropout-83            [-1, 128, 8, 8]               0
#            Conv2d-84            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-85            [-1, 128, 8, 8]             256
#           Dropout-86            [-1, 128, 8, 8]               0
#              ReLU-87            [-1, 128, 8, 8]               0
#        BasicBlock-88            [-1, 128, 8, 8]               0
#            Conv2d-89            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-90            [-1, 128, 8, 8]             256
#              ReLU-91            [-1, 128, 8, 8]               0
#           Dropout-92            [-1, 128, 8, 8]               0
#            Conv2d-93            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-94            [-1, 128, 8, 8]             256
#           Dropout-95            [-1, 128, 8, 8]               0
#              ReLU-96            [-1, 128, 8, 8]               0
#        BasicBlock-97            [-1, 128, 8, 8]               0
#            Conv2d-98            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-99            [-1, 128, 8, 8]             256
#             ReLU-100            [-1, 128, 8, 8]               0
#          Dropout-101            [-1, 128, 8, 8]               0
#           Conv2d-102            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-103            [-1, 128, 8, 8]             256
#          Dropout-104            [-1, 128, 8, 8]               0
#             ReLU-105            [-1, 128, 8, 8]               0
#       BasicBlock-106            [-1, 128, 8, 8]               0
# AdaptiveAvgPool2d-107            [-1, 128, 1, 1]               0
#           Linear-108                   [-1, 10]           1,290
# ================================================================
# Total params: 1,177,130
# Trainable params: 1,177,130
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 16.31
# Params size (MB): 4.49
# Estimated Total Size (MB): 20.82
# ----------------------------------------------------------------

# %%
# Train model
train_model(model, train_loader, val_loader, epochs=200)
# Out:
# Epoch 1/200 - Train Loss: 1.7857, Train Acc: 32.17% | Val Loss: 1.7133, Val Acc: 37.22%
# Epoch 2/200 - Train Loss: 1.3205, Train Acc: 51.67% | Val Loss: 1.7098, Val Acc: 45.17%
# Epoch 3/200 - Train Loss: 1.0706, Train Acc: 61.63% | Val Loss: 1.4391, Val Acc: 55.32%
# Epoch 4/200 - Train Loss: 0.9271, Train Acc: 67.09% | Val Loss: 0.9904, Val Acc: 65.98%
# Epoch 5/200 - Train Loss: 0.8049, Train Acc: 71.66% | Val Loss: 0.7619, Val Acc: 74.05%
# Epoch 6/200 - Train Loss: 0.7116, Train Acc: 75.26% | Val Loss: 0.8411, Val Acc: 72.56%
# Epoch 7/200 - Train Loss: 0.6512, Train Acc: 77.49% | Val Loss: 0.6506, Val Acc: 76.92%
# Epoch 8/200 - Train Loss: 0.6141, Train Acc: 78.83% | Val Loss: 0.6494, Val Acc: 78.16%
# Epoch 9/200 - Train Loss: 0.5673, Train Acc: 80.30% | Val Loss: 0.6024, Val Acc: 79.87%
# Epoch 10/200 - Train Loss: 0.5471, Train Acc: 81.20% | Val Loss: 0.5689, Val Acc: 81.23%
# Epoch 11/200 - Train Loss: 0.5234, Train Acc: 81.95% | Val Loss: 0.6077, Val Acc: 80.21%
# Epoch 12/200 - Train Loss: 0.5048, Train Acc: 82.51% | Val Loss: 0.5922, Val Acc: 80.98%
# Epoch 13/200 - Train Loss: 0.4927, Train Acc: 83.13% | Val Loss: 0.6779, Val Acc: 78.14%
# Epoch 14/200 - Train Loss: 0.4858, Train Acc: 83.35% | Val Loss: 0.6571, Val Acc: 79.71%
# Epoch 15/200 - Train Loss: 0.4690, Train Acc: 83.68% | Val Loss: 0.5548, Val Acc: 81.49%
# Epoch 16/200 - Train Loss: 0.4565, Train Acc: 84.32% | Val Loss: 0.4724, Val Acc: 83.88%
# Epoch 17/200 - Train Loss: 0.4482, Train Acc: 84.55% | Val Loss: 0.5764, Val Acc: 81.17%
# Epoch 18/200 - Train Loss: 0.4402, Train Acc: 84.94% | Val Loss: 0.5103, Val Acc: 83.37%
# Epoch 19/200 - Train Loss: 0.4302, Train Acc: 85.20% | Val Loss: 0.5717, Val Acc: 81.38%
# Epoch 20/200 - Train Loss: 0.4259, Train Acc: 85.29% | Val Loss: 0.5312, Val Acc: 82.83%
# Epoch 21/200 - Train Loss: 0.4158, Train Acc: 85.81% | Val Loss: 0.6091, Val Acc: 80.58%
# Epoch 22/200 - Train Loss: 0.4134, Train Acc: 85.72% | Val Loss: 0.4445, Val Acc: 84.57%
# Epoch 23/200 - Train Loss: 0.4071, Train Acc: 85.90% | Val Loss: 0.6193, Val Acc: 81.05%
# Epoch 24/200 - Train Loss: 0.4000, Train Acc: 86.18% | Val Loss: 0.5187, Val Acc: 83.53%
# Epoch 25/200 - Train Loss: 0.3968, Train Acc: 86.31% | Val Loss: 0.4411, Val Acc: 85.51%
# Epoch 26/200 - Train Loss: 0.3935, Train Acc: 86.36% | Val Loss: 0.4407, Val Acc: 85.52%
# Epoch 27/200 - Train Loss: 0.3922, Train Acc: 86.53% | Val Loss: 0.4416, Val Acc: 84.84%
# Epoch 28/200 - Train Loss: 0.3846, Train Acc: 86.76% | Val Loss: 0.4525, Val Acc: 85.31%
# Epoch 29/200 - Train Loss: 0.3799, Train Acc: 86.98% | Val Loss: 0.4586, Val Acc: 85.05%
# Epoch 30/200 - Train Loss: 0.3785, Train Acc: 86.89% | Val Loss: 0.5437, Val Acc: 83.60%
# Epoch 31/200 - Train Loss: 0.3730, Train Acc: 87.16% | Val Loss: 0.4367, Val Acc: 85.68%
# Epoch 32/200 - Train Loss: 0.3733, Train Acc: 87.10% | Val Loss: 0.4935, Val Acc: 84.28%
# Epoch 33/200 - Train Loss: 0.3717, Train Acc: 87.19% | Val Loss: 0.4883, Val Acc: 83.46%
# Epoch 34/200 - Train Loss: 0.3702, Train Acc: 86.99% | Val Loss: 0.4819, Val Acc: 84.26%
# Epoch 35/200 - Train Loss: 0.3612, Train Acc: 87.57% | Val Loss: 0.5307, Val Acc: 83.09%
# Epoch 36/200 - Train Loss: 0.3649, Train Acc: 87.43% | Val Loss: 0.4560, Val Acc: 84.90%
# Epoch 37/200 - Train Loss: 0.3609, Train Acc: 87.56% | Val Loss: 0.4353, Val Acc: 85.32%
# Epoch 38/200 - Train Loss: 0.3549, Train Acc: 87.65% | Val Loss: 0.5476, Val Acc: 82.86%
# Epoch 39/200 - Train Loss: 0.3573, Train Acc: 87.65% | Val Loss: 0.4456, Val Acc: 85.52%
# Epoch 40/200 - Train Loss: 0.3569, Train Acc: 87.73% | Val Loss: 0.4740, Val Acc: 84.84%
# Epoch 41/200 - Train Loss: 0.3590, Train Acc: 87.59% | Val Loss: 0.5089, Val Acc: 84.20%
# Epoch 42/200 - Train Loss: 0.3591, Train Acc: 87.58% | Val Loss: 0.4419, Val Acc: 85.47%
# Epoch 43/200 - Train Loss: 0.3539, Train Acc: 87.74% | Val Loss: 0.4751, Val Acc: 85.15%
# Epoch 44/200 - Train Loss: 0.3506, Train Acc: 87.97% | Val Loss: 0.4055, Val Acc: 87.04%
# Epoch 45/200 - Train Loss: 0.3506, Train Acc: 87.83% | Val Loss: 0.3974, Val Acc: 87.41%
# Epoch 46/200 - Train Loss: 0.3509, Train Acc: 87.81% | Val Loss: 0.6366, Val Acc: 81.03%
# Epoch 47/200 - Train Loss: 0.3463, Train Acc: 88.03% | Val Loss: 0.4358, Val Acc: 85.43%
# Epoch 48/200 - Train Loss: 0.3454, Train Acc: 88.15% | Val Loss: 0.4279, Val Acc: 86.11%
# Epoch 49/200 - Train Loss: 0.3531, Train Acc: 87.84% | Val Loss: 0.3657, Val Acc: 87.87%
# Epoch 50/200 - Train Loss: 0.3394, Train Acc: 88.34% | Val Loss: 0.4790, Val Acc: 84.72%
# Epoch 51/200 - Train Loss: 0.3479, Train Acc: 88.09% | Val Loss: 0.4118, Val Acc: 86.20%
# Epoch 52/200 - Train Loss: 0.3409, Train Acc: 88.34% | Val Loss: 0.4584, Val Acc: 85.39%
# Epoch 53/200 - Train Loss: 0.3423, Train Acc: 88.28% | Val Loss: 0.4965, Val Acc: 84.46%
# Epoch 54/200 - Train Loss: 0.3360, Train Acc: 88.42% | Val Loss: 0.4312, Val Acc: 85.88%
# Epoch 55/200 - Train Loss: 0.3388, Train Acc: 88.22% | Val Loss: 0.4626, Val Acc: 85.89%
# Epoch 56/200 - Train Loss: 0.3383, Train Acc: 88.31% | Val Loss: 0.3977, Val Acc: 86.81%
# Epoch 57/200 - Train Loss: 0.3368, Train Acc: 88.33% | Val Loss: 0.4028, Val Acc: 86.51%
# Epoch 58/200 - Train Loss: 0.3345, Train Acc: 88.50% | Val Loss: 0.5326, Val Acc: 83.70%
# Epoch 59/200 - Train Loss: 0.3324, Train Acc: 88.60% | Val Loss: 0.5306, Val Acc: 83.19%
# Epoch 60/200 - Train Loss: 0.3378, Train Acc: 88.31% | Val Loss: 0.3547, Val Acc: 88.29%
# Epoch 61/200 - Train Loss: 0.3364, Train Acc: 88.29% | Val Loss: 0.4491, Val Acc: 85.51%
# Epoch 62/200 - Train Loss: 0.3296, Train Acc: 88.52% | Val Loss: 0.4509, Val Acc: 85.13%
# Epoch 63/200 - Train Loss: 0.3290, Train Acc: 88.60% | Val Loss: 0.4906, Val Acc: 83.98%
# Epoch 64/200 - Train Loss: 0.3291, Train Acc: 88.74% | Val Loss: 0.5259, Val Acc: 83.78%
# Epoch 65/200 - Train Loss: 0.3304, Train Acc: 88.66% | Val Loss: 0.5654, Val Acc: 82.88%
# Epoch 66/200 - Train Loss: 0.3342, Train Acc: 88.45% | Val Loss: 0.5333, Val Acc: 83.76%
# Epoch 67/200 - Train Loss: 0.3274, Train Acc: 88.75% | Val Loss: 0.4894, Val Acc: 85.17%
# Epoch 68/200 - Train Loss: 0.3298, Train Acc: 88.80% | Val Loss: 0.5645, Val Acc: 81.76%
# Epoch 69/200 - Train Loss: 0.3293, Train Acc: 88.42% | Val Loss: 0.5044, Val Acc: 84.37%
# Epoch 70/200 - Train Loss: 0.3249, Train Acc: 88.72% | Val Loss: 0.4549, Val Acc: 85.83%
# Epoch 71/200 - Train Loss: 0.3275, Train Acc: 88.69% | Val Loss: 0.4521, Val Acc: 85.39%
# Epoch 72/200 - Train Loss: 0.3300, Train Acc: 88.77% | Val Loss: 0.5313, Val Acc: 84.19%
# Epoch 73/200 - Train Loss: 0.3245, Train Acc: 88.81% | Val Loss: 0.3586, Val Acc: 88.00%
# Epoch 74/200 - Train Loss: 0.3264, Train Acc: 88.80% | Val Loss: 0.4238, Val Acc: 86.70%
# Epoch 75/200 - Train Loss: 0.3192, Train Acc: 88.96% | Val Loss: 0.4709, Val Acc: 85.37%
# Epoch 76/200 - Train Loss: 0.3251, Train Acc: 88.79% | Val Loss: 0.4983, Val Acc: 84.65%
# Epoch 77/200 - Train Loss: 0.3197, Train Acc: 89.08% | Val Loss: 0.3806, Val Acc: 87.43%
# Epoch 78/200 - Train Loss: 0.3263, Train Acc: 88.77% | Val Loss: 0.4626, Val Acc: 85.05%
# Epoch 79/200 - Train Loss: 0.3220, Train Acc: 88.82% | Val Loss: 0.4130, Val Acc: 86.32%
# Epoch 80/200 - Train Loss: 0.3206, Train Acc: 89.04% | Val Loss: 0.4627, Val Acc: 85.19%
# Epoch 81/200 - Train Loss: 0.3251, Train Acc: 88.81% | Val Loss: 0.5910, Val Acc: 81.97%
# Epoch 82/200 - Train Loss: 0.3210, Train Acc: 88.91% | Val Loss: 0.3801, Val Acc: 87.41%
# Epoch 83/200 - Train Loss: 0.3214, Train Acc: 88.94% | Val Loss: 0.3918, Val Acc: 87.68%
# Epoch 84/200 - Train Loss: 0.3180, Train Acc: 89.03% | Val Loss: 0.3879, Val Acc: 87.58%
# Epoch 85/200 - Train Loss: 0.3202, Train Acc: 88.97% | Val Loss: 0.6173, Val Acc: 81.64%
# Epoch 86/200 - Train Loss: 0.3241, Train Acc: 88.81% | Val Loss: 0.4786, Val Acc: 85.32%
# Epoch 87/200 - Train Loss: 0.3133, Train Acc: 89.15% | Val Loss: 0.3664, Val Acc: 87.52%
# Epoch 88/200 - Train Loss: 0.3203, Train Acc: 89.01% | Val Loss: 0.4173, Val Acc: 86.53%
# Epoch 89/200 - Train Loss: 0.3175, Train Acc: 89.04% | Val Loss: 0.3880, Val Acc: 87.10%
# Epoch 90/200 - Train Loss: 0.3216, Train Acc: 88.83% | Val Loss: 0.4013, Val Acc: 86.79%
# Epoch 91/200 - Train Loss: 0.2022, Train Acc: 93.07% | Val Loss: 0.2127, Val Acc: 92.95%
# Epoch 92/200 - Train Loss: 0.1681, Train Acc: 94.42% | Val Loss: 0.2012, Val Acc: 93.26%
# Epoch 93/200 - Train Loss: 0.1507, Train Acc: 94.81% | Val Loss: 0.2026, Val Acc: 93.25%
# Epoch 94/200 - Train Loss: 0.1416, Train Acc: 95.21% | Val Loss: 0.2004, Val Acc: 93.39%
# Epoch 95/200 - Train Loss: 0.1319, Train Acc: 95.54% | Val Loss: 0.1967, Val Acc: 93.66%
# Epoch 96/200 - Train Loss: 0.1276, Train Acc: 95.69% | Val Loss: 0.1995, Val Acc: 93.52%
# Epoch 97/200 - Train Loss: 0.1232, Train Acc: 95.73% | Val Loss: 0.2044, Val Acc: 93.39%
# Epoch 98/200 - Train Loss: 0.1190, Train Acc: 95.89% | Val Loss: 0.2005, Val Acc: 93.30%
# Epoch 99/200 - Train Loss: 0.1138, Train Acc: 96.12% | Val Loss: 0.1965, Val Acc: 93.56%
# Epoch 100/200 - Train Loss: 0.1072, Train Acc: 96.32% | Val Loss: 0.2021, Val Acc: 93.38%
# Epoch 101/200 - Train Loss: 0.1093, Train Acc: 96.24% | Val Loss: 0.2091, Val Acc: 93.46%
# Epoch 102/200 - Train Loss: 0.1043, Train Acc: 96.47% | Val Loss: 0.2051, Val Acc: 93.53%
# Epoch 103/200 - Train Loss: 0.0994, Train Acc: 96.58% | Val Loss: 0.2075, Val Acc: 93.71%
# Epoch 104/200 - Train Loss: 0.0985, Train Acc: 96.63% | Val Loss: 0.2110, Val Acc: 93.48%
# Epoch 105/200 - Train Loss: 0.0945, Train Acc: 96.79% | Val Loss: 0.2047, Val Acc: 93.87%
# Epoch 106/200 - Train Loss: 0.0915, Train Acc: 96.85% | Val Loss: 0.2099, Val Acc: 93.29%
# Epoch 107/200 - Train Loss: 0.0922, Train Acc: 96.83% | Val Loss: 0.2148, Val Acc: 93.48%
# Epoch 108/200 - Train Loss: 0.0912, Train Acc: 96.85% | Val Loss: 0.2132, Val Acc: 93.53%
# Epoch 109/200 - Train Loss: 0.0903, Train Acc: 96.83% | Val Loss: 0.2086, Val Acc: 93.49%
# Epoch 110/200 - Train Loss: 0.0867, Train Acc: 96.95% | Val Loss: 0.2098, Val Acc: 93.72%
# Epoch 111/200 - Train Loss: 0.0850, Train Acc: 97.11% | Val Loss: 0.2109, Val Acc: 93.67%
# Epoch 112/200 - Train Loss: 0.0852, Train Acc: 97.14% | Val Loss: 0.2206, Val Acc: 93.53%
# Epoch 113/200 - Train Loss: 0.0835, Train Acc: 97.13% | Val Loss: 0.2104, Val Acc: 93.69%
# Epoch 114/200 - Train Loss: 0.0834, Train Acc: 97.07% | Val Loss: 0.2139, Val Acc: 93.61%
# Epoch 115/200 - Train Loss: 0.0814, Train Acc: 97.15% | Val Loss: 0.2066, Val Acc: 93.99%
# Epoch 116/200 - Train Loss: 0.0780, Train Acc: 97.32% | Val Loss: 0.2167, Val Acc: 93.82%
# Epoch 117/200 - Train Loss: 0.0775, Train Acc: 97.35% | Val Loss: 0.2187, Val Acc: 93.84%
# Epoch 118/200 - Train Loss: 0.0785, Train Acc: 97.27% | Val Loss: 0.2220, Val Acc: 93.44%
# Epoch 119/200 - Train Loss: 0.0758, Train Acc: 97.41% | Val Loss: 0.2183, Val Acc: 93.51%
# Epoch 120/200 - Train Loss: 0.0751, Train Acc: 97.39% | Val Loss: 0.2156, Val Acc: 93.89%
# Epoch 121/200 - Train Loss: 0.0748, Train Acc: 97.42% | Val Loss: 0.2160, Val Acc: 93.76%
# Epoch 122/200 - Train Loss: 0.0750, Train Acc: 97.47% | Val Loss: 0.2156, Val Acc: 93.57%
# Epoch 123/200 - Train Loss: 0.0783, Train Acc: 97.31% | Val Loss: 0.2154, Val Acc: 93.66%
# Epoch 124/200 - Train Loss: 0.0699, Train Acc: 97.64% | Val Loss: 0.2162, Val Acc: 93.96%
# Epoch 125/200 - Train Loss: 0.0718, Train Acc: 97.56% | Val Loss: 0.2102, Val Acc: 93.87%
# Epoch 126/200 - Train Loss: 0.0703, Train Acc: 97.64% | Val Loss: 0.2174, Val Acc: 93.82%
# Epoch 127/200 - Train Loss: 0.0702, Train Acc: 97.57% | Val Loss: 0.2221, Val Acc: 93.68%
# Epoch 128/200 - Train Loss: 0.0724, Train Acc: 97.52% | Val Loss: 0.2240, Val Acc: 93.63%
# Epoch 129/200 - Train Loss: 0.0726, Train Acc: 97.51% | Val Loss: 0.2371, Val Acc: 93.19%
# Epoch 130/200 - Train Loss: 0.0708, Train Acc: 97.52% | Val Loss: 0.2246, Val Acc: 93.47%
# Epoch 131/200 - Train Loss: 0.0723, Train Acc: 97.51% | Val Loss: 0.2308, Val Acc: 93.54%
# Epoch 132/200 - Train Loss: 0.0730, Train Acc: 97.51% | Val Loss: 0.2353, Val Acc: 93.57%
# Epoch 133/200 - Train Loss: 0.0721, Train Acc: 97.52% | Val Loss: 0.2322, Val Acc: 93.32%
# Epoch 134/200 - Train Loss: 0.0693, Train Acc: 97.62% | Val Loss: 0.2225, Val Acc: 93.61%
# Epoch 135/200 - Train Loss: 0.0740, Train Acc: 97.48% | Val Loss: 0.2318, Val Acc: 93.17%
# Epoch 136/200 - Train Loss: 0.0711, Train Acc: 97.59% | Val Loss: 0.2331, Val Acc: 93.51%
# Epoch 137/200 - Train Loss: 0.0702, Train Acc: 97.61% | Val Loss: 0.2300, Val Acc: 93.36%
# Epoch 138/200 - Train Loss: 0.0734, Train Acc: 97.50% | Val Loss: 0.2418, Val Acc: 93.02%
# Epoch 139/200 - Train Loss: 0.0748, Train Acc: 97.40% | Val Loss: 0.2270, Val Acc: 93.46%
# Epoch 140/200 - Train Loss: 0.0715, Train Acc: 97.55% | Val Loss: 0.2405, Val Acc: 93.21%
# Epoch 141/200 - Train Loss: 0.0734, Train Acc: 97.51% | Val Loss: 0.2395, Val Acc: 93.28%
# Epoch 142/200 - Train Loss: 0.0741, Train Acc: 97.37% | Val Loss: 0.2360, Val Acc: 93.01%
# Epoch 143/200 - Train Loss: 0.0711, Train Acc: 97.54% | Val Loss: 0.2465, Val Acc: 93.08%
# Epoch 144/200 - Train Loss: 0.0682, Train Acc: 97.71% | Val Loss: 0.2363, Val Acc: 93.29%
# Epoch 145/200 - Train Loss: 0.0709, Train Acc: 97.55% | Val Loss: 0.2681, Val Acc: 92.64%
# Epoch 146/200 - Train Loss: 0.0742, Train Acc: 97.49% | Val Loss: 0.2264, Val Acc: 93.60%
# Epoch 147/200 - Train Loss: 0.0708, Train Acc: 97.55% | Val Loss: 0.2340, Val Acc: 93.19%
# Epoch 148/200 - Train Loss: 0.0724, Train Acc: 97.51% | Val Loss: 0.2442, Val Acc: 93.09%
# Epoch 149/200 - Train Loss: 0.0747, Train Acc: 97.43% | Val Loss: 0.2431, Val Acc: 93.30%
# Epoch 150/200 - Train Loss: 0.0705, Train Acc: 97.61% | Val Loss: 0.2449, Val Acc: 93.16%
# Epoch 151/200 - Train Loss: 0.0716, Train Acc: 97.54% | Val Loss: 0.2379, Val Acc: 93.41%
# Epoch 152/200 - Train Loss: 0.0729, Train Acc: 97.52% | Val Loss: 0.2424, Val Acc: 93.27%
# Epoch 153/200 - Train Loss: 0.0769, Train Acc: 97.35% | Val Loss: 0.2375, Val Acc: 93.30%
# Epoch 154/200 - Train Loss: 0.0740, Train Acc: 97.47% | Val Loss: 0.2527, Val Acc: 93.21%
# Epoch 155/200 - Train Loss: 0.0738, Train Acc: 97.48% | Val Loss: 0.2576, Val Acc: 92.94%
# Epoch 156/200 - Train Loss: 0.0777, Train Acc: 97.24% | Val Loss: 0.2587, Val Acc: 92.88%
# Epoch 157/200 - Train Loss: 0.0754, Train Acc: 97.38% | Val Loss: 0.2329, Val Acc: 93.35%
# Epoch 158/200 - Train Loss: 0.0768, Train Acc: 97.33% | Val Loss: 0.2431, Val Acc: 92.89%
# Epoch 159/200 - Train Loss: 0.0727, Train Acc: 97.55% | Val Loss: 0.2616, Val Acc: 92.79%
# Epoch 160/200 - Train Loss: 0.0727, Train Acc: 97.46% | Val Loss: 0.2301, Val Acc: 93.45%
# Epoch 161/200 - Train Loss: 0.0760, Train Acc: 97.38% | Val Loss: 0.2465, Val Acc: 92.95%
# Epoch 162/200 - Train Loss: 0.0738, Train Acc: 97.52% | Val Loss: 0.2636, Val Acc: 92.75%
# Epoch 163/200 - Train Loss: 0.0748, Train Acc: 97.42% | Val Loss: 0.2474, Val Acc: 93.19%
# Epoch 164/200 - Train Loss: 0.0765, Train Acc: 97.35% | Val Loss: 0.2322, Val Acc: 93.33%
# Epoch 165/200 - Train Loss: 0.0735, Train Acc: 97.42% | Val Loss: 0.2364, Val Acc: 93.25%
# Epoch 166/200 - Train Loss: 0.0755, Train Acc: 97.43% | Val Loss: 0.2529, Val Acc: 92.74%
# Epoch 167/200 - Train Loss: 0.0736, Train Acc: 97.45% | Val Loss: 0.2335, Val Acc: 93.51%
# Epoch 168/200 - Train Loss: 0.0753, Train Acc: 97.40% | Val Loss: 0.2650, Val Acc: 92.65%
# Epoch 169/200 - Train Loss: 0.0763, Train Acc: 97.38% | Val Loss: 0.2669, Val Acc: 92.67%
# Epoch 170/200 - Train Loss: 0.0777, Train Acc: 97.37% | Val Loss: 0.2646, Val Acc: 92.67%
# Epoch 171/200 - Train Loss: 0.0758, Train Acc: 97.39% | Val Loss: 0.2523, Val Acc: 92.75%
# Epoch 172/200 - Train Loss: 0.0735, Train Acc: 97.50% | Val Loss: 0.2518, Val Acc: 93.26%
# Epoch 173/200 - Train Loss: 0.0780, Train Acc: 97.30% | Val Loss: 0.2315, Val Acc: 93.15%
# Epoch 174/200 - Train Loss: 0.0743, Train Acc: 97.48% | Val Loss: 0.2324, Val Acc: 93.34%
# Epoch 175/200 - Train Loss: 0.0731, Train Acc: 97.53% | Val Loss: 0.2446, Val Acc: 93.14%
# Epoch 176/200 - Train Loss: 0.0749, Train Acc: 97.41% | Val Loss: 0.2748, Val Acc: 92.51%
# Epoch 177/200 - Train Loss: 0.0750, Train Acc: 97.47% | Val Loss: 0.2455, Val Acc: 93.21%
# Epoch 178/200 - Train Loss: 0.0763, Train Acc: 97.39% | Val Loss: 0.2509, Val Acc: 92.76%
# Epoch 179/200 - Train Loss: 0.0789, Train Acc: 97.27% | Val Loss: 0.2523, Val Acc: 92.94%
# Epoch 180/200 - Train Loss: 0.0768, Train Acc: 97.37% | Val Loss: 0.2585, Val Acc: 92.63%
# Epoch 181/200 - Train Loss: 0.0500, Train Acc: 98.44% | Val Loss: 0.2088, Val Acc: 93.86%
# Epoch 182/200 - Train Loss: 0.0385, Train Acc: 98.84% | Val Loss: 0.2015, Val Acc: 93.96%
# Epoch 183/200 - Train Loss: 0.0358, Train Acc: 98.96% | Val Loss: 0.2017, Val Acc: 94.39%
# Epoch 184/200 - Train Loss: 0.0322, Train Acc: 99.08% | Val Loss: 0.1998, Val Acc: 94.46%
# Epoch 185/200 - Train Loss: 0.0309, Train Acc: 99.10% | Val Loss: 0.1975, Val Acc: 94.33%
# Epoch 186/200 - Train Loss: 0.0302, Train Acc: 99.09% | Val Loss: 0.1980, Val Acc: 94.49%
# Epoch 187/200 - Train Loss: 0.0284, Train Acc: 99.19% | Val Loss: 0.1978, Val Acc: 94.43%
# Epoch 188/200 - Train Loss: 0.0272, Train Acc: 99.21% | Val Loss: 0.1965, Val Acc: 94.61%
# Epoch 189/200 - Train Loss: 0.0284, Train Acc: 99.16% | Val Loss: 0.1973, Val Acc: 94.55%
# Epoch 190/200 - Train Loss: 0.0261, Train Acc: 99.27% | Val Loss: 0.1967, Val Acc: 94.46%
# Epoch 191/200 - Train Loss: 0.0243, Train Acc: 99.36% | Val Loss: 0.1972, Val Acc: 94.53%
# Epoch 192/200 - Train Loss: 0.0268, Train Acc: 99.21% | Val Loss: 0.1994, Val Acc: 94.56%
# Epoch 193/200 - Train Loss: 0.0235, Train Acc: 99.38% | Val Loss: 0.2002, Val Acc: 94.52%
# Epoch 194/200 - Train Loss: 0.0254, Train Acc: 99.32% | Val Loss: 0.2003, Val Acc: 94.54%
# Epoch 195/200 - Train Loss: 0.0238, Train Acc: 99.34% | Val Loss: 0.2002, Val Acc: 94.54%
# Epoch 196/200 - Train Loss: 0.0230, Train Acc: 99.38% | Val Loss: 0.1997, Val Acc: 94.52%
# Epoch 197/200 - Train Loss: 0.0241, Train Acc: 99.32% | Val Loss: 0.2033, Val Acc: 94.38%
# Epoch 198/200 - Train Loss: 0.0241, Train Acc: 99.30% | Val Loss: 0.2004, Val Acc: 94.57%
# Epoch 199/200 - Train Loss: 0.0226, Train Acc: 99.35% | Val Loss: 0.1992, Val Acc: 94.48%
# Epoch 200/200 - Train Loss: 0.0216, Train Acc: 99.41% | Val Loss: 0.2021, Val Acc: 94.47%

# %%
model.eval()
predictions = []
with torch.no_grad():
    for batch in test_loader:
        images = batch[0].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())

# Generate submission file
submission = pd.DataFrame({'ID': np.arange(len(predictions)), 'Labels': predictions})
submission.to_csv('predictins_v2.0_jv3.csv', index=False)
print("Predictions file saved.")
# Out:
# Predictions file saved.
